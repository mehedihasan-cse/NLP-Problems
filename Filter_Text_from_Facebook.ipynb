# %% [markdown]
# <a href="https://colab.research.google.com/github/mehedihasan-cse/NLP-Problems/blob/main/Filter_Text_from_Facebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/ESUIT _ Comments Exporter for Facebook™ (42).csv')

# %%
df.head(2)
# Out:
#                                                   Id           UserId  \
# 0  Y29tbWVudDo1Mjc3Njc1ODMwOTg3NDJfODY5Mjk2MTE1MT...  100075965132688
# 1  Y29tbWVudDo1Mjc3Njc1ODMwOTg3NDJfMTA0OTEwMDI1Nj...  100045376111136
#
#                                               Avatar       Author  \
# 0  https://scontent.fdac45-1.fna.fbcdn.net/v/t39....  Alif Mahmud
# 1  https://scontent.fdac45-1.fna.fbcdn.net/v/t39....   Ro Omar TP
#
#                                              Content  \
# 0  পবিত্র কাবা সাথে কিছু তুলনা করা বকামি ছাড়া আর ...
# 1            -Alif Mahmud Welcome to Rohingya camp 😅
#
#                                                  Url  ReactionsCount  Depth  \
# 0  https://www.facebook.com/alifmahmud19/posts/pf...             257      0
# 1  https://www.facebook.com/alifmahmud19/posts/pf...               4      1
#
#    SubCommentsCount               CommentAt
# 0                 7  08/18/2024 06:22:38 PM
# 1                 0  08/18/2024 06:25:43 PM

# %%
df.columns
# Out:
# Index(['Id', 'UserId', 'Avatar', 'Author', 'Content', 'Url', 'ReactionsCount',
#        'Depth', 'SubCommentsCount', 'CommentAt'],
#       dtype='object')

# %%
df = df.drop(columns = ['Id', 'UserId', 'Avatar', 'Author', 'Url', 'ReactionsCount',
       'Depth', 'SubCommentsCount', 'CommentAt'])
df
# Out:
#                                               Content
# 0   পবিত্র কাবা সাথে কিছু তুলনা করা বকামি ছাড়া আর ...
# 1             -Alif Mahmud Welcome to Rohingya camp 😅
# 2   -Alif Mahmud saudi arabe amader dukane ashlen ...
# 3   -Alif Mahmud  Vaiye deka korte cai ami Apnar sate
# 4                            -Alif Mahmud যে বুঝদার 😝
# 5   -Alif Mahmud এই মাত্র দেখা হলো কক্সবাজার আপনার...
# 6         -Alif Mahmud Vaiye Deka korte cai Apnr sate
# 7                              অভিনন্দন প্রিয় ভাই ❤️🥰
# 8         ছোট বড় সব সময় সবার পাশে আছি ইনশাল্লাহ 🥰❤️
# 9                                             ঠিক আছে
# 10                       প্রিয় জায়গা মক্কা মদিনা🥰❤️
# 11                                -Md Babul Rana সহমত
# 12  পৃথিবীর মধ্যে সবচেয়ে প্রিয় জায়গা কক্সবাজার ...
# 13  -এক একজনের পছন্দ একেক রকম হওয়াটাই স্বাভাবিক م...
# 14  -শোয়াইব বিন শফিক বিভিন্ন জনকে বিভিন্ন জায়গা ...
# 15  -শোয়াইব বিন শফিক ভাই ওনার লেখা আবার দেখতে পার...
# ...

# %%
df.dropna()
# Out:
#                                               Content
# 0   পবিত্র কাবা সাথে কিছু তুলনা করা বকামি ছাড়া আর ...
# 1             -Alif Mahmud Welcome to Rohingya camp 😅
# 2   -Alif Mahmud saudi arabe amader dukane ashlen ...
# 3   -Alif Mahmud  Vaiye deka korte cai ami Apnar sate
# 4                            -Alif Mahmud যে বুঝদার 😝
# 5   -Alif Mahmud এই মাত্র দেখা হলো কক্সবাজার আপনার...
# 6         -Alif Mahmud Vaiye Deka korte cai Apnr sate
# 7                              অভিনন্দন প্রিয় ভাই ❤️🥰
# 8         ছোট বড় সব সময় সবার পাশে আছি ইনশাল্লাহ 🥰❤️
# 9                                             ঠিক আছে
# 10                       প্রিয় জায়গা মক্কা মদিনা🥰❤️
# 11                                -Md Babul Rana সহমত
# 12  পৃথিবীর মধ্যে সবচেয়ে প্রিয় জায়গা কক্সবাজার ...
# 13  -এক একজনের পছন্দ একেক রকম হওয়াটাই স্বাভাবিক م...
# 14  -শোয়াইব বিন শফিক বিভিন্ন জনকে বিভিন্ন জায়গা ...
# 15  -শোয়াইব বিন শফিক ভাই ওনার লেখা আবার দেখতে পার...
# ...

# %%
import re

def has_english(row):
    # Check if the 'Content' column contains any English letters
    content = row['Content']
    if isinstance(content, str):  # Check if content is a string
        return bool(re.search(r'[a-zA-Z]', content))
    else:
        return False  # Return False for non-string values

# Filter the DataFrame to keep only rows without English letters
df = df[~df.apply(has_english, axis=1)]
df
# Out:
#                                               Content
# 0   পবিত্র কাবা সাথে কিছু তুলনা করা বকামি ছাড়া আর ...
# 7                              অভিনন্দন প্রিয় ভাই ❤️🥰
# 8         ছোট বড় সব সময় সবার পাশে আছি ইনশাল্লাহ 🥰❤️
# 9                                             ঠিক আছে
# 10                       প্রিয় জায়গা মক্কা মদিনা🥰❤️
# 12  পৃথিবীর মধ্যে সবচেয়ে প্রিয় জায়গা কক্সবাজার ...
# 13  -এক একজনের পছন্দ একেক রকম হওয়াটাই স্বাভাবিক م...
# 14  -শোয়াইব বিন শফিক বিভিন্ন জনকে বিভিন্ন জায়গা ...
# 15  -শোয়াইব বিন শফিক ভাই ওনার লেখা আবার দেখতে পার...
# 16                   -শোয়াইব বিন শফিক  আমিও বুঝলামনা
# 17                                           অভিনন্দন
# 18           -ইদ্রিস ভাই 01 আপনার ভালোবাসা চাই ভাই 🙏🙏
# 20  এত দিন বলেছেন পৃথিবীর মদ্ধে সব থেকে প্রিয় জায়গ...
# 22                                                 ❣️
# 23                  💞💞💞 কক্সবাজারে আপনাকে স্বাগতম,, 🎋
# 24         ভাই আপনার সাথে দেখা করেত চায় কক্সবাজার আছি
# ...

# %%
import string
punct=string.punctuation

# %%
def remove_punct(x):
    if isinstance(x, str):  # Check if x is a string
        return x.translate(str.maketrans("", "", punct))
    else:
        return x  # Return the original value if it's not a string

df['Content'] = df['Content'].apply(lambda x: remove_punct(x))
# Out:
# <ipython-input-153-cdef42da0f2b>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Content'] = df['Content'].apply(lambda x: remove_punct(x))

# %%
df.isna().sum()
# Out:
# Content    0
# dtype: int64

# %%
df['Target'] = 0
# Out:
# <ipython-input-155-3c1d3cc14786>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Target'] = 0

# %%
df
# Out:
#                                               Content  Target
# 0   পবিত্র কাবা সাথে কিছু তুলনা করা বকামি ছাড়া আর ...       0
# 7                              অভিনন্দন প্রিয় ভাই ❤️🥰       0
# 8         ছোট বড় সব সময় সবার পাশে আছি ইনশাল্লাহ 🥰❤️       0
# 9                                             ঠিক আছে       0
# 10                       প্রিয় জায়গা মক্কা মদিনা🥰❤️       0
# 12  পৃথিবীর মধ্যে সবচেয়ে প্রিয় জায়গা কক্সবাজার ...       0
# 13  এক একজনের পছন্দ একেক রকম হওয়াটাই স্বাভাবিক ما...       0
# 14  শোয়াইব বিন শফিক বিভিন্ন জনকে বিভিন্ন জায়গা ভ...       0
# 15    শোয়াইব বিন শফিক ভাই ওনার লেখা আবার দেখতে পারেন       0
# 16                    শোয়াইব বিন শফিক  আমিও বুঝলামনা       0
# 17                                           অভিনন্দন       0
# 18            ইদ্রিস ভাই 01 আপনার ভালোবাসা চাই ভাই 🙏🙏       0
# 20  এত দিন বলেছেন পৃথিবীর মদ্ধে সব থেকে প্রিয় জায়গ...       0
# 22                                                 ❣️       0
# ...

# %%
from google.colab import files

# %%
df.to_csv('/content/modified_data.csv', index=False)

# %%
from google.colab import files
files.download('/content/modified_data.csv')  # Make sure this path matches the file you saved
